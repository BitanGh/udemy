# %% [markdown]
# <a href="https://colab.research.google.com/github/BitanGh/udemy/blob/main/Data_Visualization_using_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme(style="darkgrid")
dataset = sns.load_dataset("tips")
dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['sex', 'smoker', 'day', 'time'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
sns.scatterplot(x="total_bill", y="tip", data=dataset)
plt.title("Scatter Plot")
plt.show()

# %%
#Creating a LinePlot
sns.lineplot(x="total_bill", y="tip", data=dataset)
plt.title("Line Plot")
plt.show()

# %%
#Creating a CategoricalPlot
sns.barplot(x="day", y="total_bill", data=dataset)
plt.title("Categorical Bar Plot")
plt.show()

# %%
#Boxplot
sns.boxplot(x="day", y="total_bill", data=dataset)
plt.title("Box Plot")
plt.show()

# %%
#Histogram plot
sns.histplot(dataset["total_bill"], bins= 10, kde=True)
plt.title("Histogram Plot")
# Out:
# Text(0.5, 1.0, 'Histogram Plot')

# %%
#PairPlot
sns.pairplot(dataset)

# %%
#Heatmap
corr = dataset[["total_bill","tip","size"]].corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
# Out:
# <Axes: >
